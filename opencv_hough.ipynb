# %%
#Sobel filter

import cv2
import numpy as np
img = cv2.imread('lena.png', cv2.IMREAD_GRAYSCALE)
rows, cols = img.shape
# It is used depth of cv2.CV_64F.
sobel_horizontal = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)
# 水平方向一次微分，k 平滑化程度
# Kernel size can be: 1,3,5 or 7.
sobel_vertical = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)

sobel_horizontal_abs = np.absolute(sobel_horizontal)
sobel_horizontal_8u = np.uint8(sobel_horizontal_abs)

sobel_vertical_abs = np.absolute(sobel_vertical)
sobel_vertical_8u = np.uint8(sobel_vertical_abs)

cv2.imshow('Original', img)
cv2.imshow('Sobel horizontal', sobel_horizontal_8u)
cv2.imshow('Sobel vertical', sobel_vertical_8u)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#canny edge detector

import cv2
import matplotlib.pyplot as plt

image = cv2.imread('lena.png')
#sigma to detect fine/coarse feature
image = cv2.GaussianBlur(image,(5,5),0)

edges = cv2.Canny(image, 50, 210)
# 投票 ，進一步判斷
plt.figure(figsize=(8,5))
plt.subplot(1,2,1)
plt.axis('off')
plt.title('original')
plt.imshow(image[:,:,[2,1,0]]) #rgb >bgr

plt.subplot(1,2,2)
plt.axis('off')
plt.title('edges')
plt.imshow(edges, cmap='gray')

plt.tight_layout()
plt.show()

# %%
#Hough transform

import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('red_blood_cell.jpg', cv2.IMREAD_GRAYSCALE)
rows, cols = img.shape
# 起終點，顏色，粗度

#[0]最前面list 

img1 = cv2.Canny(img, 150, 200)
circles = cv2.HoughCircles(img, cv2.HOUGH_GRADIENT, 1,
                           2, param1=100, param2=25, minRadius=1, maxRadius=30)[0]
dbg_img = np.zeros((img.shape[0], img.shape[1], 3), np.uint8)
number = 0 
for c in circles:
    number = number + 1
    print('Detected circle: center=({} {}), radius={}'.format(c[0], c[1], c[2]))
    cv2.circle(dbg_img, (int (c[0]), int(c[1])), int(c[2]), (0, 255, 0), 1)

cv2.putText(dbg_img, str(number), (10, 40), cv2.FONT_HERSHEY_SIMPLEX,
            1, (255, 255, 255), 3, cv2.LINE_AA)

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.title('original')
plt.axis('off')
plt.imshow(img, cmap='gray')


plt.subplot(1,2,2)
plt.title('detected primitives')
plt.axis('off')
plt.imshow(dbg_img)

plt.show()
# Out:
# Detected circle: center=(25.5 98.5), radius=9.600000381469727
# Detected circle: center=(195.5 95.5), radius=9.399999618530273
# Detected circle: center=(145.5 218.5), radius=9.600000381469727
# Detected circle: center=(139.5 9.5), radius=9.600000381469727
# Detected circle: center=(169.5 166.5), radius=9.399999618530273
# Detected circle: center=(194.5 183.5), radius=10.5
# Detected circle: center=(100.5 94.5), radius=9.100000381469727
# Detected circle: center=(155.5 181.5), radius=9.600000381469727
# Detected circle: center=(262.5 163.5), radius=9.399999618530273
# Detected circle: center=(87.5 51.5), radius=8.199999809265137
# Detected circle: center=(297.5 217.5), radius=8.199999809265137
# Detected circle: center=(262.5 135.5), radius=9.600000381469727
# Detected circle: center=(260.5 30.5), radius=10.0
# Detected circle: center=(122.5 221.5), radius=9.600000381469727
# Detected circle: center=(48.5 198.5), radius=8.199999809265137
# Detected circle: center=(220.5 74.5), radius=9.399999618530273
# Detected circle: center=(47.5 24.5), radius=9.100000381469727
# Detected circle: center=(29.5 192.5), radius=8.800000190734863
# Detected circle: center=(262.5 107.5), radius=8.699999809265137
# Detected circle: center=(145.5 33.5), radius=11.600000381469727
# Detected circle: center=(106.5 43.5), radius=9.100000381469727
# Detected circle: center=(49.5 52.5), radius=10.5
# Detected circle: center=(130.5 184.5), radius=9.600000381469727
# Detected circle: center=(288.5 164.5), radius=9.600000381469727
# Detected circle: center=(214.5 48.5), radius=9.399999618530273
# Detected circle: center=(279.5 51.5), radius=11.0
# Detected circle: center=(68.5 40.5), radius=10.300000190734863
# Detected circle: center=(79.5 143.5), radius=9.600000381469727
# Detected circle: center=(96.5 13.5), radius=9.600000381469727
# Detected circle: center=(145.5 164.5), radius=9.600000381469727
# Detected circle: center=(27.5 63.5), radius=9.100000381469727
# Detected circle: center=(66.5 206.5), radius=8.199999809265137
# Detected circle: center=(98.5 118.5), radius=9.399999618530273
# Detected circle: center=(114.5 200.5), radius=9.100000381469727
# Detected circle: center=(253.5 72.5), radius=8.399999618530273
# Detected circle: center=(64.5 189.5), radius=8.0
# Detected circle: center=(200.5 27.5), radius=10.300000190734863
# Detected circle: center=(190.5 42.5), radius=10.0
# Detected circle: center=(281.5 97.5), radius=9.600000381469727
# Detected circle: center=(145.5 31.5), radius=9.100000381469727
# Detected circle: center=(210.5 199.5), radius=8.800000190734863
# Detected circle: center=(12.5 228.5), radius=8.399999618530273
# Detected circle: center=(228.5 222.5), radius=8.199999809265137
# Detected circle: center=(242.5 125.5), radius=8.199999809265137
# Detected circle: center=(107.5 65.5), radius=8.199999809265137
# Detected circle: center=(76.5 111.5), radius=8.0
# Detected circle: center=(114.5 202.5), radius=11.0
# Detected circle: center=(74.5 19.5), radius=9.600000381469727
# Detected circle: center=(90.5 222.5), radius=9.600000381469727
# Detected circle: center=(193.5 72.5), radius=9.600000381469727
# Detected circle: center=(212.5 155.5), radius=8.199999809265137
# Detected circle: center=(270.5 210.5), radius=8.199999809265137
# Detected circle: center=(132.5 145.5), radius=7.400000095367432
# Detected circle: center=(299.5 149.5), radius=7.300000190734863
# Detected circle: center=(44.5 116.5), radius=10.300000190734863
# Detected circle: center=(127.5 126.5), radius=9.600000381469727
# Detected circle: center=(167.5 221.5), radius=9.600000381469727
# Detected circle: center=(46.5 180.5), radius=9.399999618530273
# Detected circle: center=(55.5 98.5), radius=9.399999618530273
# Detected circle: center=(195.5 72.5), radius=9.399999618530273
# Detected circle: center=(98.5 161.5), radius=8.800000190734863
# Detected circle: center=(48.5 139.5), radius=8.0
# Detected circle: center=(281.5 143.5), radius=7.400000095367432
# Detected circle: center=(286.5 10.5), radius=7.400000095367432
# Detected circle: center=(64.5 205.5), radius=10.300000190734863
# Detected circle: center=(88.5 34.5), radius=10.300000190734863
# Detected circle: center=(132.5 86.5), radius=9.100000381469727
# Detected circle: center=(192.5 155.5), radius=8.800000190734863
# Detected circle: center=(280.5 32.5), radius=7.400000095367432
# Detected circle: center=(50.5 219.5), radius=10.199999809265137
# Detected circle: center=(75.5 21.5), radius=10.0
# Detected circle: center=(118.5 17.5), radius=9.100000381469727
# Detected circle: center=(254.5 183.5), radius=9.100000381469727
# Detected circle: center=(62.5 163.5), radius=8.800000190734863
# Detected circle: center=(151.5 75.5), radius=8.399999618530273
# Detected circle: center=(163.5 129.5), radius=8.399999618530273
# Detected circle: center=(109.5 143.5), radius=8.199999809265137
# Detected circle: center=(7.5 67.5), radius=7.400000095367432
# Detected circle: center=(30.5 148.5), radius=7.400000095367432
# Detected circle: center=(28.5 173.5), radius=10.300000190734863
# Detected circle: center=(145.5 166.5), radius=10.199999809265137
# Detected circle: center=(248.5 1.5), radius=10.0
# Detected circle: center=(8.5 11.5), radius=9.100000381469727
# Detected circle: center=(253.5 186.5), radius=9.100000381469727
# Detected circle: center=(282.5 31.5), radius=9.100000381469727
# Detected circle: center=(243.5 100.5), radius=9.0
# Detected circle: center=(90.5 75.5), radius=8.199999809265137
# Detected circle: center=(223.5 96.5), radius=8.199999809265137
# Detected circle: center=(259.5 55.5), radius=8.0
# Detected circle: center=(171.5 37.5), radius=11.600000381469727
# Detected circle: center=(31.5 43.5), radius=11.399999618530273
# Detected circle: center=(121.5 103.5), radius=9.600000381469727
# Detected circle: center=(241.5 196.5), radius=9.399999618530273
# Detected circle: center=(76.5 88.5), radius=9.100000381469727
# Detected circle: center=(87.5 182.5), radius=9.100000381469727
# Detected circle: center=(18.5 208.5), radius=8.0
# Detected circle: center=(146.5 28.5), radius=12.699999809265137
# Detected circle: center=(156.5 183.5), radius=10.5
# Detected circle: center=(207.5 5.5), radius=10.5
# Detected circle: center=(50.5 200.5), radius=10.0
# Detected circle: center=(125.5 125.5), radius=10.0
# Detected circle: center=(4.5 87.5), radius=9.300000190734863
# Detected circle: center=(166.5 89.5), radius=8.199999809265137
# Detected circle: center=(89.5 32.5), radius=8.0
# Detected circle: center=(131.5 143.5), radius=12.199999809265137
# Detected circle: center=(204.5 133.5), radius=9.600000381469727
# Detected circle: center=(242.5 36.5), radius=9.100000381469727
# Detected circle: center=(271.5 74.5), radius=9.100000381469727
# Detected circle: center=(107.5 143.5), radius=8.800000190734863
# Detected circle: center=(22.5 119.5), radius=8.0
# Detected circle: center=(119.5 105.5), radius=8.0

# %% [markdown]
# ###### %%writefile test
# ## Practice
# 1. Input images from red_blood_cell.jpg.
# 2. Use morphological filters to remove noise.
# 3. Use <i>cv2.HoughCircles()</i> to detect circles.
# 4. Count automatically how many cells in the image.
# 5. Optional:Use <i>cv2.ConnectedComponents()</i> to show each circle using different color.
# 6. Use <i>cv2.putText()</i> to write the number of cells on the upper left corner.
# 7. Show the output image.
# 8. Upload your Jupyter code file (*.ipynb)
# ![red_blood_cell.jpg](attachment:red_blood_cell.jpg)

# %%
#canny edge detector

import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread('lena.png')
#sigma to detect fine/coarse feature
image = cv2.GaussianBlur(image, (5, 5), 0)

edges = cv2.Canny(image, 50, 210)
# 投票 ，進一步判斷
plt.figure(figsize=(8, 5))
plt.subplot(1, 2, 1)
plt.axis('off')
plt.title('original')
plt.imshow(image[:, :, [2, 1, 0]])  # rgb >bgr

plt.subplot(1, 2, 2)
plt.axis('off')
plt.title('edges')
plt.imshow(edges, cmap='gray')

plt.tight_layout()
plt.show()
